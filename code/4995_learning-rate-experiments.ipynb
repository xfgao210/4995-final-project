# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision.models import efficientnet_v2_s, EfficientNet_V2_S_Weights
from torchvision.transforms.autoaugment import AutoAugmentPolicy

from diffusers import StableDiffusionPipeline

from torch.utils.data import Dataset, DataLoader, BatchSampler, random_split
from torchvision import transforms
from PIL import Image

# %%
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train_images/283.jpg
#   inflating: __MACOSX/data/train_images/._283.jpg
#   inflating: data/train_images/4647.jpg
#   inflating: __MACOSX/data/train_images/._4647.jpg
#   inflating: data/train_images/3128.jpg
#   inflating: __MACOSX/data/train_images/._3128.jpg
#   inflating: data/train_images/2236.jpg
#   inflating: __MACOSX/data/train_images/._2236.jpg
#   inflating: data/train_images/5559.jpg
#   inflating: __MACOSX/data/train_images/._5559.jpg
#   inflating: data/train_images/6050.jpg
#   inflating: __MACOSX/data/train_images/._6050.jpg
#   inflating: data/train_images/1059.jpg
#   inflating: __MACOSX/data/train_images/._1059.jpg
#   inflating: data/train_images/3896.jpg
#   inflating: __MACOSX/data/train_images/._3896.jpg
#   inflating: data/train_images/2550.jpg
#   inflating: __MACOSX/data/train_images/._2550.jpg
#   inflating: data/train_images/4121.jpg
#   inflating: __MACOSX/data/train_images/._4121.jpg
#   inflating: data/train_images/3882.jpg
#   inflating: __MACOSX/data/train_images/._3882.jpg
#   inflating: data/train_images/2544.jpg
#   inflating: __MACOSX/data/train_images/._2544.jpg
#   inflating: data/train_images/4135.jpg
#   inflating: __MACOSX/data/train_images/._4135.jpg
#   inflating: data/train_images/6044.jpg
#   inflating: __MACOSX/data/train_images/._6044.jpg
#   inflating: data/train_images/4653.jpg
#   inflating: __MACOSX/data/train_images/._4653.jpg
#   inflating: data/train_images/2222.jpg
#   inflating: __MACOSX/data/train_images/._2222.jpg
#   inflating: data/train_images/4914.jpg
#   inflating: __MACOSX/data/train_images/._4914.jpg
#   inflating: data/train_images/320.jpg
#   inflating: __MACOSX/data/train_images/._320.jpg
#   inflating: data/train_images/446.jpg
#   inflating: __MACOSX/data/train_images/._446.jpg
#   inflating: data/train_images/3909.jpg
#   inflating: __MACOSX/data/train_images/._3909.jpg
#   inflating: data/train_images/452.jpg
#   inflating: __MACOSX/data/train_images/._452.jpg
#   inflating: data/train_images/334.jpg
#   inflating: __MACOSX/data/train_images/._334.jpg
#   inflating: data/train_images/1878.jpg
#   inflating: __MACOSX/data/train_images/._1878.jpg
#   inflating: data/train_images/4900.jpg
#   inflating: __MACOSX/data/train_images/._4900.jpg
#   inflating: data/train_images/1688.jpg
#   inflating: __MACOSX/data/train_images/._1688.jpg
#   inflating: data/train_images/1850.jpg
#   inflating: __MACOSX/data/train_images/._1850.jpg
#   inflating: data/train_images/4928.jpg
#   inflating: __MACOSX/data/train_images/._4928.jpg
#   inflating: data/train_images/2381.jpg
#   inflating: __MACOSX/data/train_images/._2381.jpg
#   inflating: data/train_images/5388.jpg
#   inflating: __MACOSX/data/train_images/._5388.jpg
#   inflating: data/train_images/3921.jpg
#   inflating: __MACOSX/data/train_images/._3921.jpg
#   inflating: data/train_images/4096.jpg
#   inflating: __MACOSX/data/train_images/._4096.jpg
#   inflating: data/train_images/3935.jpg
#   inflating: __MACOSX/data/train_images/._3935.jpg
#   inflating: data/train_images/4082.jpg
#   inflating: __MACOSX/data/train_images/._4082.jpg
#   inflating: data/train_images/2395.jpg
#   inflating: __MACOSX/data/train_images/._2395.jpg
#   inflating: data/train_images/308.jpg
#   inflating: __MACOSX/data/train_images/._308.jpg
#   inflating: data/train_images/1844.jpg
#   inflating: __MACOSX/data/train_images/._1844.jpg
#   inflating: data/train_images/1677.jpg
#   inflating: __MACOSX/data/train_images/._1677.jpg
#   inflating: data/train_images/6118.jpg
#   inflating: __MACOSX/data/train_images/._6118.jpg
#   inflating: data/train_images/5411.jpg
#   inflating: __MACOSX/data/train_images/._5411.jpg
#   inflating: data/train_images/3060.jpg
#   inflating: __MACOSX/data/train_images/._3060.jpg
#   inflating: data/train_images/4069.jpg
#   inflating: __MACOSX/data/train_images/._4069.jpg
#   inflating: data/train_images/3706.jpg
#   inflating: __MACOSX/data/train_images/._3706.jpg
#   inflating: data/train_images/2418.jpg
#   inflating: __MACOSX/data/train_images/._2418.jpg
#   inflating: data/train_images/5377.jpg
#   inflating: __MACOSX/data/train_images/._5377.jpg
#   inflating: data/train_images/485.jpg
#   inflating: __MACOSX/data/train_images/._485.jpg
#   inflating: data/train_images/1111.jpg
#   inflating: __MACOSX/data/train_images/._1111.jpg
#   inflating: data/train_images/1105.jpg
#   inflating: __MACOSX/data/train_images/._1105.jpg
#   inflating: data/train_images/491.jpg
#   inflating: __MACOSX/data/train_images/._491.jpg
#   inflating: data/train_images/3712.jpg
#   inflating: __MACOSX/data/train_images/._3712.jpg
#   inflating: data/train_images/5363.jpg
#   inflating: __MACOSX/data/train_images/._5363.jpg
#   inflating: data/train_images/5405.jpg
#   inflating: __MACOSX/data/train_images/._5405.jpg
#   inflating: data/train_images/3074.jpg
#   inflating: __MACOSX/data/train_images/._3074.jpg
#   inflating: data/train_images/1663.jpg
#   inflating: __MACOSX/data/train_images/._1663.jpg
#   inflating: data/train_images/2342.jpg
#   inflating: __MACOSX/data/train_images/._2342.jpg
#   inflating: data/train_images/4733.jpg
#   inflating: __MACOSX/data/train_images/._4733.jpg
#   inflating: data/train_images/1893.jpg
#   inflating: __MACOSX/data/train_images/._1893.jpg
#   inflating: data/train_images/6124.jpg
#   inflating: __MACOSX/data/train_images/._6124.jpg
#   inflating: data/train_images/4055.jpg
#   inflating: __MACOSX/data/train_images/._4055.jpg
#   inflating: data/train_images/2424.jpg
#   inflating: __MACOSX/data/train_images/._2424.jpg
#   inflating: data/train_images/4041.jpg
#   inflating: __MACOSX/data/train_images/._4041.jpg
#   inflating: data/train_images/2430.jpg
#   inflating: __MACOSX/data/train_images/._2430.jpg
#   inflating: data/train_images/1139.jpg
#   inflating: __MACOSX/data/train_images/._1139.jpg
#   inflating: data/train_images/1887.jpg
#   inflating: __MACOSX/data/train_images/._1887.jpg
#   inflating: data/train_images/6130.jpg
#   inflating: __MACOSX/data/train_images/._6130.jpg
#   inflating: data/train_images/5439.jpg
#   inflating: __MACOSX/data/train_images/._5439.jpg
#   inflating: data/train_images/2356.jpg
#   inflating: __MACOSX/data/train_images/._2356.jpg
#   inflating: data/train_images/3048.jpg
#   inflating: __MACOSX/data/train_images/._3048.jpg
#   inflating: data/train_images/4727.jpg
#   inflating: __MACOSX/data/train_images/._4727.jpg
#   inflating: data/train_images/2801.jpg
#   inflating: __MACOSX/data/train_images/._2801.jpg
#   inflating: data/train_images/644.jpg
#   inflating: __MACOSX/data/train_images/._644.jpg
#   inflating: data/train_images/122.jpg
#   inflating: __MACOSX/data/train_images/._122.jpg
#   inflating: data/train_images/5808.jpg
#   inflating: __MACOSX/data/train_images/._5808.jpg
#   inflating: data/train_images/136.jpg
#   inflating: __MACOSX/data/train_images/._136.jpg
#   inflating: data/train_images/650.jpg
#   inflating: __MACOSX/data/train_images/._650.jpg
#   inflating: data/train_images/888.jpg
#   inflating: __MACOSX/data/train_images/._888.jpg
#   inflating: data/train_images/2815.jpg
#   inflating: __MACOSX/data/train_images/._2815.jpg
#   inflating: data/train_images/678.jpg
#   inflating: __MACOSX/data/train_images/._678.jpg
#   inflating: data/train_images/4294.jpg
#   inflating: __MACOSX/data/train_images/._4294.jpg
#   inflating: data/train_images/2183.jpg
#   inflating: __MACOSX/data/train_images/._2183.jpg
#   inflating: data/train_images/5834.jpg
#   inflating: __MACOSX/data/train_images/._5834.jpg
#   inflating: data/train_images/2197.jpg
#   inflating: __MACOSX/data/train_images/._2197.jpg
#   inflating: data/train_images/3289.jpg
#   inflating: __MACOSX/data/train_images/._3289.jpg
#   inflating: data/train_images/5820.jpg
#   inflating: __MACOSX/data/train_images/._5820.jpg
#   inflating: data/train_images/2829.jpg
#   inflating: __MACOSX/data/train_images/._2829.jpg
#   inflating: data/train_images/4280.jpg
#   inflating: __MACOSX/data/train_images/._4280.jpg
#   inflating: data/train_images/1313.jpg
#   inflating: __MACOSX/data/train_images/._1313.jpg
#   inflating: data/train_images/687.jpg
#   inflating: __MACOSX/data/train_images/._687.jpg
#   inflating: data/train_images/5175.jpg
#   inflating: __MACOSX/data/train_images/._5175.jpg
#   inflating: data/train_images/3504.jpg
#   inflating: __MACOSX/data/train_images/._3504.jpg
#   inflating: data/train_images/3262.jpg
#   inflating: __MACOSX/data/train_images/._3262.jpg
#   inflating: data/train_images/5613.jpg
#   inflating: __MACOSX/data/train_images/._5613.jpg
#   inflating: data/train_images/1475.jpg
#   inflating: __MACOSX/data/train_images/._1475.jpg
#   inflating: data/train_images/1461.jpg
#   inflating: __MACOSX/data/train_images/._1461.jpg
#   inflating: data/train_images/4519.jpg
#   inflating: __MACOSX/data/train_images/._4519.jpg
#   inflating: data/train_images/3276.jpg
#   inflating: __MACOSX/data/train_images/._3276.jpg
#   inflating: data/train_images/2168.jpg
#   inflating: __MACOSX/data/train_images/._2168.jpg
#   inflating: data/train_images/5607.jpg
#   inflating: __MACOSX/data/train_images/._5607.jpg
#   inflating: data/train_images/5161.jpg
#   inflating: __MACOSX/data/train_images/._5161.jpg
#   inflating: data/train_images/3510.jpg
#   inflating: __MACOSX/data/train_images/._3510.jpg
#   inflating: data/train_images/693.jpg
#   inflating: __MACOSX/data/train_images/._693.jpg
#   inflating: data/train_images/1307.jpg
#   inflating: __MACOSX/data/train_images/._1307.jpg
#   inflating: data/train_images/5149.jpg
#   inflating: __MACOSX/data/train_images/._5149.jpg
#   inflating: data/train_images/2626.jpg
#   inflating: __MACOSX/data/train_images/._2626.jpg
#   inflating: data/train_images/3538.jpg
#   inflating: __MACOSX/data/train_images/._3538.jpg
#   inflating: data/train_images/4257.jpg
#   inflating: __MACOSX/data/train_images/._4257.jpg
#   inflating: data/train_images/863.jpg
#   inflating: __MACOSX/data/train_images/._863.jpg
#   inflating: data/train_images/23.jpg
#   inflating: __MACOSX/data/train_images/._23.jpg
#   inflating: data/train_images/1449.jpg
#   inflating: __MACOSX/data/train_images/._1449.jpg
#   inflating: data/train_images/4531.jpg
#   inflating: __MACOSX/data/train_images/._4531.jpg
#   inflating: data/train_images/2140.jpg
#   inflating: __MACOSX/data/train_images/._2140.jpg
#   inflating: data/train_images/4525.jpg
#   inflating: __MACOSX/data/train_images/._4525.jpg
#   inflating: data/train_images/2154.jpg
#   inflating: __MACOSX/data/train_images/._2154.jpg
#   inflating: data/train_images/877.jpg
#   inflating: __MACOSX/data/train_images/._877.jpg
#   inflating: data/train_images/37.jpg
#   inflating: __MACOSX/data/train_images/._37.jpg
#   inflating: data/train_images/2632.jpg
#   inflating: __MACOSX/data/train_images/._2632.jpg
#   inflating: data/train_images/4243.jpg
#   inflating: __MACOSX/data/train_images/._4243.jpg
#   inflating: data/train_images/1303.jpg
#   inflating: __MACOSX/data/train_images/._1303.jpg
#   inflating: data/train_images/697.jpg
#   inflating: __MACOSX/data/train_images/._697.jpg
#   inflating: data/train_images/3514.jpg
#   inflating: __MACOSX/data/train_images/._3514.jpg
#   inflating: data/train_images/5165.jpg
#   inflating: __MACOSX/data/train_images/._5165.jpg
#   inflating: data/train_images/5603.jpg
#   inflating: __MACOSX/data/train_images/._5603.jpg
#   inflating: data/train_images/3272.jpg
#   inflating: __MACOSX/data/train_images/._3272.jpg
#   inflating: data/train_images/1465.jpg
#   inflating: __MACOSX/data/train_images/._1465.jpg
#   inflating: data/train_images/1471.jpg
#   inflating: __MACOSX/data/train_images/._1471.jpg
#   inflating: data/train_images/2178.jpg
#   inflating: __MACOSX/data/train_images/._2178.jpg
#   inflating: data/train_images/5617.jpg
#   inflating: __MACOSX/data/train_images/._5617.jpg
#   inflating: data/train_images/4509.jpg
#   inflating: __MACOSX/data/train_images/._4509.jpg
#   inflating: data/train_images/3266.jpg
#   inflating: __MACOSX/data/train_images/._3266.jpg
#   inflating: data/train_images/3500.jpg
#   inflating: __MACOSX/data/train_images/._3500.jpg
#   inflating: data/train_images/5171.jpg
#   inflating: __MACOSX/data/train_images/._5171.jpg
#   inflating: data/train_images/683.jpg
#   inflating: __MACOSX/data/train_images/._683.jpg
#   inflating: data/train_images/1317.jpg
#   inflating: __MACOSX/data/train_images/._1317.jpg
#   inflating: data/train_images/3528.jpg
#   inflating: __MACOSX/data/train_images/._3528.jpg
#   inflating: data/train_images/4247.jpg
#   inflating: __MACOSX/data/train_images/._4247.jpg
#   inflating: data/train_images/5159.jpg
#   inflating: __MACOSX/data/train_images/._5159.jpg
#   inflating: data/train_images/2636.jpg
#   inflating: __MACOSX/data/train_images/._2636.jpg
#   inflating: data/train_images/33.jpg
#   inflating: __MACOSX/data/train_images/._33.jpg
#   inflating: data/train_images/873.jpg
#   inflating: __MACOSX/data/train_images/._873.jpg
#   inflating: data/train_images/1459.jpg
#   inflating: __MACOSX/data/train_images/._1459.jpg
#   inflating: data/train_images/2150.jpg
#   inflating: __MACOSX/data/train_images/._2150.jpg
#   inflating: data/train_images/4521.jpg
#   inflating: __MACOSX/data/train_images/._4521.jpg
#   inflating: data/train_images/2144.jpg
#   inflating: __MACOSX/data/train_images/._2144.jpg
#   inflating: data/train_images/4535.jpg
#   inflating: __MACOSX/data/train_images/._4535.jpg
#   inflating: data/train_images/27.jpg
#   inflating: __MACOSX/data/train_images/._27.jpg
#   inflating: data/train_images/867.jpg
#   inflating: __MACOSX/data/train_images/._867.jpg
#   inflating: data/train_images/4253.jpg
#   inflating: __MACOSX/data/train_images/._4253.jpg
#   inflating: data/train_images/2622.jpg
#   inflating: __MACOSX/data/train_images/._2622.jpg
#   inflating: data/train_images/2811.jpg
#   inflating: __MACOSX/data/train_images/._2811.jpg
#   inflating: data/train_images/654.jpg
#   inflating: __MACOSX/data/train_images/._654.jpg
#   inflating: data/train_images/132.jpg
#   inflating: __MACOSX/data/train_images/._132.jpg
#   inflating: data/train_images/5818.jpg
#   inflating: __MACOSX/data/train_images/._5818.jpg
#   inflating: data/train_images/126.jpg
#   inflating: __MACOSX/data/train_images/._126.jpg
#   inflating: data/train_images/898.jpg
#   inflating: __MACOSX/data/train_images/._898.jpg
#   inflating: data/train_images/640.jpg
#   inflating: __MACOSX/data/train_images/._640.jpg
#   inflating: data/train_images/2805.jpg
#   inflating: __MACOSX/data/train_images/._2805.jpg
#   inflating: data/train_images/668.jpg
#   inflating: __MACOSX/data/train_images/._668.jpg
#   inflating: data/train_images/4284.jpg
#   inflating: __MACOSX/data/train_images/._4284.jpg
#   inflating: data/train_images/5824.jpg
#   inflating: __MACOSX/data/train_images/._5824.jpg
#   inflating: data/train_images/2193.jpg
#   inflating: __MACOSX/data/train_images/._2193.jpg
#   inflating: data/train_images/5830.jpg
#   inflating: __MACOSX/data/train_images/._5830.jpg
#   inflating: data/train_images/3299.jpg
#   inflating: __MACOSX/data/train_images/._3299.jpg
#   inflating: data/train_images/2187.jpg
#   inflating: __MACOSX/data/train_images/._2187.jpg
#   inflating: data/train_images/4290.jpg
#   inflating: __MACOSX/data/train_images/._4290.jpg
#   inflating: data/train_images/2839.jpg
#   inflating: __MACOSX/data/train_images/._2839.jpg
#   inflating: data/train_images/1667.jpg
#   inflating: __MACOSX/data/train_images/._1667.jpg
#   inflating: data/train_images/6108.jpg
#   inflating: __MACOSX/data/train_images/._6108.jpg
#   inflating: data/train_images/3070.jpg
#   inflating: __MACOSX/data/train_images/._3070.jpg
#   inflating: data/train_images/5401.jpg
#   inflating: __MACOSX/data/train_images/._5401.jpg
#   inflating: data/train_images/2408.jpg
#   inflating: __MACOSX/data/train_images/._2408.jpg
#   inflating: data/train_images/5367.jpg
#   inflating: __MACOSX/data/train_images/._5367.jpg
#   inflating: data/train_images/4079.jpg
#   inflating: __MACOSX/data/train_images/._4079.jpg
#   inflating: data/train_images/3716.jpg
#   inflating: __MACOSX/data/train_images/._3716.jpg
#   inflating: data/train_images/495.jpg
#   inflating: __MACOSX/data/train_images/._495.jpg
#   inflating: data/train_images/1101.jpg
#   inflating: __MACOSX/data/train_images/._1101.jpg
#   inflating: data/train_images/1115.jpg
#   inflating: __MACOSX/data/train_images/._1115.jpg
#   inflating: data/train_images/481.jpg
#   inflating: __MACOSX/data/train_images/._481.jpg
#   inflating: data/train_images/5373.jpg
#   inflating: __MACOSX/data/train_images/._5373.jpg
#   inflating: data/train_images/3702.jpg
#   inflating: __MACOSX/data/train_images/._3702.jpg
#   inflating: data/train_images/3064.jpg
#   inflating: __MACOSX/data/train_images/._3064.jpg
#   inflating: data/train_images/5415.jpg
#   inflating: __MACOSX/data/train_images/._5415.jpg
#   inflating: data/train_images/1673.jpg
#   inflating: __MACOSX/data/train_images/._1673.jpg
#   inflating: data/train_images/4723.jpg
#   inflating: __MACOSX/data/train_images/._4723.jpg
#   inflating: data/train_images/2352.jpg
#   inflating: __MACOSX/data/train_images/._2352.jpg
#   inflating: data/train_images/6134.jpg
#   inflating: __MACOSX/data/train_images/._6134.jpg
#   inflating: data/train_images/1883.jpg
#   inflating: __MACOSX/data/train_images/._1883.jpg
#   inflating: data/train_images/2434.jpg
#   inflating: __MACOSX/data/train_images/._2434.jpg
#   inflating: data/train_images/4045.jpg
#   inflating: __MACOSX/data/train_images/._4045.jpg
#   inflating: data/train_images/2420.jpg
#   inflating: __MACOSX/data/train_images/._2420.jpg
#   inflating: data/train_images/4051.jpg
#   inflating: __MACOSX/data/train_images/._4051.jpg
#   inflating: data/train_images/1129.jpg
#   inflating: __MACOSX/data/train_images/._1129.jpg
#   inflating: data/train_images/6120.jpg
#   inflating: __MACOSX/data/train_images/._6120.jpg
#   inflating: data/train_images/1897.jpg
#   inflating: __MACOSX/data/train_images/._1897.jpg
#   inflating: data/train_images/3058.jpg
#   inflating: __MACOSX/data/train_images/._3058.jpg
#   inflating: data/train_images/4737.jpg
#   inflating: __MACOSX/data/train_images/._4737.jpg
#   inflating: data/train_images/5429.jpg
#   inflating: __MACOSX/data/train_images/._5429.jpg
#   inflating: data/train_images/2346.jpg
#   inflating: __MACOSX/data/train_images/._2346.jpg
#   inflating: data/train_images/4904.jpg
#   inflating: __MACOSX/data/train_images/._4904.jpg
#   inflating: data/train_images/330.jpg
#   inflating: __MACOSX/data/train_images/._330.jpg
#   inflating: data/train_images/456.jpg
#   inflating: __MACOSX/data/train_images/._456.jpg
#   inflating: data/train_images/3919.jpg
#   inflating: __MACOSX/data/train_images/._3919.jpg
#   inflating: data/train_images/442.jpg
#   inflating: __MACOSX/data/train_images/._442.jpg
#   inflating: data/train_images/1868.jpg
#   inflating: __MACOSX/data/train_images/._1868.jpg
#   inflating: data/train_images/324.jpg
#   inflating: __MACOSX/data/train_images/._324.jpg
#   inflating: data/train_images/4910.jpg
#   inflating: __MACOSX/data/train_images/._4910.jpg
#   inflating: data/train_images/1840.jpg
#   inflating: __MACOSX/data/train_images/._1840.jpg
#   inflating: data/train_images/1698.jpg
#   inflating: __MACOSX/data/train_images/._1698.jpg
#   inflating: data/train_images/2391.jpg
#   inflating: __MACOSX/data/train_images/._2391.jpg
#   inflating: data/train_images/4938.jpg
#   inflating: __MACOSX/data/train_images/._4938.jpg
#   inflating: data/train_images/4086.jpg
#   inflating: __MACOSX/data/train_images/._4086.jpg
#   inflating: data/train_images/3931.jpg
#   inflating: __MACOSX/data/train_images/._3931.jpg
#   inflating: data/train_images/5398.jpg
#   inflating: __MACOSX/data/train_images/._5398.jpg
#   inflating: data/train_images/4092.jpg
#   inflating: __MACOSX/data/train_images/._4092.jpg
#   inflating: data/train_images/3925.jpg
#   inflating: __MACOSX/data/train_images/._3925.jpg
#   inflating: data/train_images/2385.jpg
#   inflating: __MACOSX/data/train_images/._2385.jpg
#   inflating: data/train_images/1854.jpg
#   inflating: __MACOSX/data/train_images/._1854.jpg
#   inflating: data/train_images/318.jpg
#   inflating: __MACOSX/data/train_images/._318.jpg
#   inflating: data/train_images/287.jpg
#   inflating: __MACOSX/data/train_images/._287.jpg
#   inflating: data/train_images/1713.jpg
#   inflating: __MACOSX/data/train_images/._1713.jpg
#   inflating: data/train_images/5575.jpg
#   inflating: __MACOSX/data/train_images/._5575.jpg
#   inflating: data/train_images/3104.jpg
#   inflating: __MACOSX/data/train_images/._3104.jpg
#   inflating: data/train_images/3662.jpg
#   inflating: __MACOSX/data/train_images/._3662.jpg
#   inflating: data/train_images/5213.jpg
#   inflating: __MACOSX/data/train_images/._5213.jpg
#   inflating: data/train_images/1075.jpg
#   inflating: __MACOSX/data/train_images/._1075.jpg
#   inflating: data/train_images/1061.jpg
#   inflating: __MACOSX/data/train_images/._1061.jpg
#   inflating: data/train_images/3676.jpg
#   inflating: __MACOSX/data/train_images/._3676.jpg
#   inflating: data/train_images/4119.jpg
#   inflating: __MACOSX/data/train_images/._4119.jpg
#   inflating: data/train_images/5207.jpg
#   inflating: __MACOSX/data/train_images/._5207.jpg
#   inflating: data/train_images/2568.jpg
#   inflating: __MACOSX/data/train_images/._2568.jpg
#   inflating: data/train_images/5561.jpg
#   inflating: __MACOSX/data/train_images/._5561.jpg
#   inflating: data/train_images/3110.jpg
#   inflating: __MACOSX/data/train_images/._3110.jpg
#   inflating: data/train_images/6068.jpg
#   inflating: __MACOSX/data/train_images/._6068.jpg
#   inflating: data/train_images/1707.jpg
#   inflating: __MACOSX/data/train_images/._1707.jpg
#   inflating: data/train_images/293.jpg
#   inflating: __MACOSX/data/train_images/._293.jpg
#   inflating: data/train_images/2226.jpg
#   inflating: __MACOSX/data/train_images/._2226.jpg
#   inflating: data/train_images/5549.jpg
#   inflating: __MACOSX/data/train_images/._5549.jpg
#   inflating: data/train_images/4657.jpg
#   inflating: __MACOSX/data/train_images/._4657.jpg
#   inflating: data/train_images/3138.jpg
#   inflating: __MACOSX/data/train_images/._3138.jpg
#   inflating: data/train_images/6040.jpg
#   inflating: __MACOSX/data/train_images/._6040.jpg
#   inflating: data/train_images/1049.jpg
#   inflating: __MACOSX/data/train_images/._1049.jpg
#   inflating: data/train_images/4131.jpg
#   inflating: __MACOSX/data/train_images/._4131.jpg
#   inflating: data/train_images/3886.jpg
#   inflating: __MACOSX/data/train_images/._3886.jpg
#   inflating: data/train_images/2540.jpg
#   inflating: __MACOSX/data/train_images/._2540.jpg
#   inflating: data/train_images/4125.jpg
#   inflating: __MACOSX/data/train_images/._4125.jpg
#   inflating: data/train_images/3892.jpg
#   inflating: __MACOSX/data/train_images/._3892.jpg
#   inflating: data/train_images/2554.jpg
#   inflating: __MACOSX/data/train_images/._2554.jpg
#   inflating: data/train_images/6054.jpg
#   inflating: __MACOSX/data/train_images/._6054.jpg
#   inflating: data/train_images/2232.jpg
#   inflating: __MACOSX/data/train_images/._2232.jpg
#   inflating: data/train_images/4643.jpg
#   inflating: __MACOSX/data/train_images/._4643.jpg
#   inflating: data/train_images/4870.jpg
#   inflating: __MACOSX/data/train_images/._4870.jpg
#   inflating: data/train_images/244.jpg
#   inflating: __MACOSX/data/train_images/._244.jpg
#   inflating: data/train_images/1908.jpg
#   inflating: __MACOSX/data/train_images/._1908.jpg
#   inflating: data/train_images/522.jpg
#   inflating: __MACOSX/data/train_images/._522.jpg
#   inflating: data/train_images/3879.jpg
#   inflating: __MACOSX/data/train_images/._3879.jpg
#   inflating: data/train_images/536.jpg
#   inflating: __MACOSX/data/train_images/._536.jpg
#   inflating: data/train_images/250.jpg
#   inflating: __MACOSX/data/train_images/._250.jpg
#   inflating: data/train_images/4864.jpg
#   inflating: __MACOSX/data/train_images/._4864.jpg
#   inflating: data/train_images/6083.jpg
#   inflating: __MACOSX/data/train_images/._6083.jpg
#   inflating: data/train_images/278.jpg
#   inflating: __MACOSX/data/train_images/._278.jpg
#   inflating: data/train_images/1934.jpg
#   inflating: __MACOSX/data/train_images/._1934.jpg
#   inflating: data/train_images/4694.jpg
#   inflating: __MACOSX/data/train_images/._4694.jpg
#   inflating: data/train_images/3845.jpg
#   inflating: __MACOSX/data/train_images/._3845.jpg
#   inflating: data/train_images/2583.jpg
#   inflating: __MACOSX/data/train_images/._2583.jpg
#   inflating: data/train_images/3851.jpg
#   inflating: __MACOSX/data/train_images/._3851.jpg
#   inflating: data/train_images/2597.jpg
#   inflating: __MACOSX/data/train_images/._2597.jpg
#   inflating: data/train_images/3689.jpg
#   inflating: __MACOSX/data/train_images/._3689.jpg
#   inflating: data/train_images/4680.jpg
#   inflating: __MACOSX/data/train_images/._4680.jpg
#   inflating: data/train_images/4858.jpg
#   inflating: __MACOSX/data/train_images/._4858.jpg
#   inflating: data/train_images/6097.jpg
#   inflating: __MACOSX/data/train_images/._6097.jpg
#   inflating: data/train_images/1920.jpg
#   inflating: __MACOSX/data/train_images/._1920.jpg
#   inflating: data/train_images/1277.jpg
#   inflating: __MACOSX/data/train_images/._1277.jpg
#   inflating: data/train_images/5011.jpg
#   inflating: __MACOSX/data/train_images/._5011.jpg
#   inflating: data/train_images/3460.jpg
#   inflating: __MACOSX/data/train_images/._3460.jpg
#   inflating: data/train_images/3306.jpg
#   inflating: __MACOSX/data/train_images/._3306.jpg
#   inflating: data/train_images/4469.jpg
#   inflating: __MACOSX/data/train_images/._4469.jpg
#   inflating: data/train_images/5777.jpg
#   inflating: __MACOSX/data/train_images/._5777.jpg
#   inflating: data/train_images/2018.jpg
#   inflating: __MACOSX/data/train_images/._2018.jpg
#   inflating: data/train_images/1511.jpg
#   inflating: __MACOSX/data/train_images/._1511.jpg
#   inflating: data/train_images/1505.jpg
#   inflating: __MACOSX/data/train_images/._1505.jpg
#   inflating: data/train_images/3312.jpg
#   inflating: __MACOSX/data/train_images/._3312.jpg
#   inflating: data/train_images/5763.jpg
#   inflating: __MACOSX/data/train_images/._5763.jpg
#   inflating: data/train_images/5005.jpg
#   inflating: __MACOSX/data/train_images/._5005.jpg
#   inflating: data/train_images/3474.jpg
#   inflating: __MACOSX/data/train_images/._3474.jpg
#   inflating: data/train_images/1263.jpg
#   inflating: __MACOSX/data/train_images/._1263.jpg
#   inflating: data/train_images/2742.jpg
#   inflating: __MACOSX/data/train_images/._2742.jpg
#   inflating: data/train_images/4333.jpg
#   inflating: __MACOSX/data/train_images/._4333.jpg
#   inflating: data/train_images/907.jpg
#   inflating: __MACOSX/data/train_images/._907.jpg
#   inflating: data/train_images/6242.jpg
#   inflating: __MACOSX/data/train_images/._6242.jpg
#   inflating: data/train_images/5993.jpg
#   inflating: __MACOSX/data/train_images/._5993.jpg
#   inflating: data/train_images/4455.jpg
#   inflating: __MACOSX/data/train_images/._4455.jpg
#   inflating: data/train_images/2024.jpg
#   inflating: __MACOSX/data/train_images/._2024.jpg
#   inflating: data/train_images/5987.jpg
#   inflating: __MACOSX/data/train_images/._5987.jpg
#   inflating: data/train_images/4441.jpg
#   inflating: __MACOSX/data/train_images/._4441.jpg
#   inflating: data/train_images/2030.jpg
#   inflating: __MACOSX/data/train_images/._2030.jpg
#   inflating: data/train_images/1539.jpg
#   inflating: __MACOSX/data/train_images/._1539.jpg
#   inflating: data/train_images/6256.jpg
#   inflating: __MACOSX/data/train_images/._6256.jpg
#   inflating: data/train_images/913.jpg
#   inflating: __MACOSX/data/train_images/._913.jpg
#   inflating: data/train_images/2756.jpg
#   inflating: __MACOSX/data/train_images/._2756.jpg
#   inflating: data/train_images/5039.jpg
#   inflating: __MACOSX/data/train_images/._5039.jpg
#   inflating: data/train_images/4327.jpg
#   inflating: __MACOSX/data/train_images/._4327.jpg
#   inflating: data/train_images/3448.jpg
#   inflating: __MACOSX/data/train_images/._3448.jpg
#   inflating: data/train_images/2965.jpg
#   inflating: __MACOSX/data/train_images/._2965.jpg
#   inflating: data/train_images/720.jpg
#   inflating: __MACOSX/data/train_images/._720.jpg
#   inflating: data/train_images/5978.jpg
#   inflating: __MACOSX/data/train_images/._5978.jpg
#   inflating: data/train_images/734.jpg
#   inflating: __MACOSX/data/train_images/._734.jpg
#   inflating: data/train_images/2971.jpg
#   inflating: __MACOSX/data/train_images/._2971.jpg
#   inflating: data/train_images/1288.jpg
#   inflating: __MACOSX/data/train_images/._1288.jpg
#   inflating: data/train_images/2959.jpg
#   inflating: __MACOSX/data/train_images/._2959.jpg
#   inflating: data/train_images/2781.jpg
#   inflating: __MACOSX/data/train_images/._2781.jpg
#   inflating: data/train_images/5788.jpg
#   inflating: __MACOSX/data/train_images/._5788.jpg
#   inflating: data/train_images/5950.jpg
#   inflating: __MACOSX/data/train_images/._5950.jpg
#   inflating: data/train_images/4496.jpg
#   inflating: __MACOSX/data/train_images/._4496.jpg
#   inflating: data/train_images/6281.jpg
#   inflating: __MACOSX/data/train_images/._6281.jpg
#   inflating: data/train_images/5944.jpg
#   inflating: __MACOSX/data/train_images/._5944.jpg
#   inflating: data/train_images/4482.jpg
#   inflating: __MACOSX/data/train_images/._4482.jpg
#   inflating: data/train_images/2795.jpg
#   inflating: __MACOSX/data/train_images/._2795.jpg
#   inflating: data/train_images/708.jpg
#   inflating: __MACOSX/data/train_images/._708.jpg
#   inflating: data/train_images/4483.jpg
#   inflating: __MACOSX/data/train_images/._4483.jpg
#   inflating: data/train_images/5945.jpg
#   inflating: __MACOSX/data/train_images/._5945.jpg
#   inflating: data/train_images/709.jpg
#   inflating: __MACOSX/data/train_images/._709.jpg
#   inflating: data/train_images/2794.jpg
#   inflating: __MACOSX/data/train_images/._2794.jpg
#   inflating: data/train_images/2780.jpg
#   inflating: __MACOSX/data/train_images/._2780.jpg
#   inflating: data/train_images/2958.jpg
#   inflating: __MACOSX/data/train_images/._2958.jpg
#   inflating: data/train_images/1289.jpg
#   inflating: __MACOSX/data/train_images/._1289.jpg
#   inflating: data/train_images/6280.jpg
#   inflating: __MACOSX/data/train_images/._6280.jpg
#   inflating: data/train_images/4497.jpg
#   inflating: __MACOSX/data/train_images/._4497.jpg
#   inflating: data/train_images/5951.jpg
#   inflating: __MACOSX/data/train_images/._5951.jpg
#   inflating: data/train_images/5789.jpg
#   inflating: __MACOSX/data/train_images/._5789.jpg
#   inflating: data/train_images/5979.jpg
#   inflating: __MACOSX/data/train_images/._5979.jpg
#   inflating: data/train_images/2970.jpg
#   inflating: __MACOSX/data/train_images/._2970.jpg
#   inflating: data/train_images/735.jpg
#   inflating: __MACOSX/data/train_images/._735.jpg
#   inflating: data/train_images/721.jpg
#   inflating: __MACOSX/data/train_images/._721.jpg
#   inflating: data/train_images/2964.jpg
#   inflating: __MACOSX/data/train_images/._2964.jpg
#   inflating: data/train_images/6257.jpg
#   inflating: __MACOSX/data/train_images/._6257.jpg
#   inflating: data/train_images/1538.jpg
#   inflating: __MACOSX/data/train_images/._1538.jpg
#   inflating: data/train_images/2031.jpg
#   inflating: __MACOSX/data/train_images/._2031.jpg
#   inflating: data/train_images/4440.jpg
#   inflating: __MACOSX/data/train_images/._4440.jpg
#   inflating: data/train_images/5986.jpg
#   inflating: __MACOSX/data/train_images/._5986.jpg
#   inflating: data/train_images/3449.jpg
#   inflating: __MACOSX/data/train_images/._3449.jpg
#   inflating: data/train_images/4326.jpg
#   inflating: __MACOSX/data/train_images/._4326.jpg
#   inflating: data/train_images/5038.jpg
#   inflating: __MACOSX/data/train_images/._5038.jpg
#   inflating: data/train_images/2757.jpg
#   inflating: __MACOSX/data/train_images/._2757.jpg
#   inflating: data/train_images/912.jpg
#   inflating: __MACOSX/data/train_images/._912.jpg
#   inflating: data/train_images/906.jpg
#   inflating: __MACOSX/data/train_images/._906.jpg
#   inflating: data/train_images/4332.jpg
#   inflating: __MACOSX/data/train_images/._4332.jpg
#   inflating: data/train_images/2743.jpg
#   inflating: __MACOSX/data/train_images/._2743.jpg
#   inflating: data/train_images/2025.jpg
#   inflating: __MACOSX/data/train_images/._2025.jpg
#   inflating: data/train_images/4454.jpg
#   inflating: __MACOSX/data/train_images/._4454.jpg
#   inflating: data/train_images/5992.jpg
#   inflating: __MACOSX/data/train_images/._5992.jpg
#   inflating: data/train_images/6243.jpg
#   inflating: __MACOSX/data/train_images/._6243.jpg
#   inflating: data/train_images/5762.jpg
#   inflating: __MACOSX/data/train_images/._5762.jpg
#   inflating: data/train_images/3313.jpg
#   inflating: __MACOSX/data/train_images/._3313.jpg
#   inflating: data/train_images/1504.jpg
#   inflating: __MACOSX/data/train_images/._1504.jpg
#   inflating: data/train_images/1262.jpg
#   inflating: __MACOSX/data/train_images/._1262.jpg
#   inflating: data/train_images/3475.jpg
#   inflating: __MACOSX/data/train_images/._3475.jpg
#   inflating: data/train_images/5004.jpg
#   inflating: __MACOSX/data/train_images/._5004.jpg
#   inflating: data/train_images/3461.jpg
#   inflating: __MACOSX/data/train_images/._3461.jpg
#   inflating: data/train_images/5010.jpg
#   inflating: __MACOSX/data/train_images/._5010.jpg
#   inflating: data/train_images/1276.jpg
#   inflating: __MACOSX/data/train_images/._1276.jpg
#   inflating: data/train_images/1510.jpg
#   inflating: __MACOSX/data/train_images/._1510.jpg
#   inflating: data/train_images/2019.jpg
#   inflating: __MACOSX/data/train_images/._2019.jpg
#   inflating: data/train_images/5776.jpg
#   inflating: __MACOSX/data/train_images/._5776.jpg
#   inflating: data/train_images/4468.jpg
#   inflating: __MACOSX/data/train_images/._4468.jpg
#   inflating: data/train_images/3307.jpg
#   inflating: __MACOSX/data/train_images/._3307.jpg
#   inflating: data/train_images/3688.jpg
#   inflating: __MACOSX/data/train_images/._3688.jpg
#   inflating: data/train_images/2596.jpg
#   inflating: __MACOSX/data/train_images/._2596.jpg
#   inflating: data/train_images/3850.jpg
#   inflating: __MACOSX/data/train_images/._3850.jpg
#   inflating: data/train_images/1921.jpg
#   inflating: __MACOSX/data/train_images/._1921.jpg
#   inflating: data/train_images/6096.jpg
#   inflating: __MACOSX/data/train_images/._6096.jpg
#   inflating: data/train_images/4859.jpg
#   inflating: __MACOSX/data/train_images/._4859.jpg
#   inflating: data/train_images/4681.jpg
#   inflating: __MACOSX/data/train_images/._4681.jpg
#   inflating: data/train_images/4695.jpg
#   inflating: __MACOSX/data/train_images/._4695.jpg
#   inflating: data/train_images/1935.jpg
#   inflating: __MACOSX/data/train_images/._1935.jpg
#   inflating: data/train_images/279.jpg
#   inflating: __MACOSX/data/train_images/._279.jpg
#   inflating: data/train_images/6082.jpg
#   inflating: __MACOSX/data/train_images/._6082.jpg
#   inflating: data/train_images/2582.jpg
#   inflating: __MACOSX/data/train_images/._2582.jpg
#   inflating: data/train_images/3844.jpg
#   inflating: __MACOSX/data/train_images/._3844.jpg
#   inflating: data/train_images/537.jpg
#   inflating: __MACOSX/data/train_images/._537.jpg
#   inflating: data/train_images/4865.jpg
#   inflating: __MACOSX/data/train_images/._4865.jpg
#   inflating: data/train_images/251.jpg
#   inflating: __MACOSX/data/train_images/._251.jpg
#   inflating: data/train_images/1909.jpg
#   inflating: __MACOSX/data/train_images/._1909.jpg
#   inflating: data/train_images/245.jpg
#   inflating: __MACOSX/data/train_images/._245.jpg
#   inflating: data/train_images/4871.jpg
#   inflating: __MACOSX/data/train_images/._4871.jpg
#   inflating: data/train_images/3878.jpg
#   inflating: __MACOSX/data/train_images/._3878.jpg
#   inflating: data/train_images/523.jpg
#   inflating: __MACOSX/data/train_images/._523.jpg
#   inflating: data/train_images/2555.jpg
#   inflating: __MACOSX/data/train_images/._2555.jpg
#   inflating: data/train_images/3893.jpg
#   inflating: __MACOSX/data/train_images/._3893.jpg
#   inflating: data/train_images/4124.jpg
#   inflating: __MACOSX/data/train_images/._4124.jpg
#   inflating: data/train_images/4642.jpg
#   inflating: __MACOSX/data/train_images/._4642.jpg
#   inflating: data/train_images/2233.jpg
#   inflating: __MACOSX/data/train_images/._2233.jpg
#   inflating: data/train_images/6055.jpg
#   inflating: __MACOSX/data/train_images/._6055.jpg
#   inflating: data/train_images/6041.jpg
#   inflating: __MACOSX/data/train_images/._6041.jpg
#   inflating: data/train_images/3139.jpg
#   inflating: __MACOSX/data/train_images/._3139.jpg
#   inflating: data/train_images/4656.jpg
#   inflating: __MACOSX/data/train_images/._4656.jpg
#   inflating: data/train_images/5548.jpg
#   inflating: __MACOSX/data/train_images/._5548.jpg
#   inflating: data/train_images/2227.jpg
#   inflating: __MACOSX/data/train_images/._2227.jpg
#   inflating: data/train_images/2541.jpg
#   inflating: __MACOSX/data/train_images/._2541.jpg
#   inflating: data/train_images/3887.jpg
#   inflating: __MACOSX/data/train_images/._3887.jpg
#   inflating: data/train_images/4130.jpg
#   inflating: __MACOSX/data/train_images/._4130.jpg
#   inflating: data/train_images/1048.jpg
#   inflating: __MACOSX/data/train_images/._1048.jpg
#   inflating: data/train_images/2569.jpg
#   inflating: __MACOSX/data/train_images/._2569.jpg
#   inflating: data/train_images/5206.jpg
#   inflating: __MACOSX/data/train_images/._5206.jpg
#   inflating: data/train_images/4118.jpg
#   inflating: __MACOSX/data/train_images/._4118.jpg
#   inflating: data/train_images/3677.jpg
#   inflating: __MACOSX/data/train_images/._3677.jpg
#   inflating: data/train_images/1060.jpg
#   inflating: __MACOSX/data/train_images/._1060.jpg
#   inflating: data/train_images/292.jpg
#   inflating: __MACOSX/data/train_images/._292.jpg
#   inflating: data/train_images/1706.jpg
#   inflating: __MACOSX/data/train_images/._1706.jpg
#   inflating: data/train_images/6069.jpg
#   inflating: __MACOSX/data/train_images/._6069.jpg
#   inflating: data/train_images/3111.jpg
#   inflating: __MACOSX/data/train_images/._3111.jpg
#   inflating: data/train_images/5560.jpg
#   inflating: __MACOSX/data/train_images/._5560.jpg
#   inflating: data/train_images/3105.jpg
#   inflating: __MACOSX/data/train_images/._3105.jpg
#   inflating: data/train_images/5574.jpg
#   inflating: __MACOSX/data/train_images/._5574.jpg
#   inflating: data/train_images/1712.jpg
#   inflating: __MACOSX/data/train_images/._1712.jpg
#   inflating: data/train_images/286.jpg
#   inflating: __MACOSX/data/train_images/._286.jpg
#   inflating: data/train_images/1074.jpg
#   inflating: __MACOSX/data/train_images/._1074.jpg
#   inflating: data/train_images/5212.jpg
#   inflating: __MACOSX/data/train_images/._5212.jpg
#   inflating: data/train_images/3663.jpg
#   inflating: __MACOSX/data/train_images/._3663.jpg
#   inflating: data/train_images/3924.jpg
#   inflating: __MACOSX/data/train_images/._3924.jpg
#   inflating: data/train_images/4093.jpg
#   inflating: __MACOSX/data/train_images/._4093.jpg
#   inflating: data/train_images/319.jpg
#   inflating: __MACOSX/data/train_images/._319.jpg
#   inflating: data/train_images/1855.jpg
#   inflating: __MACOSX/data/train_images/._1855.jpg
#   inflating: data/train_images/2384.jpg
#   inflating: __MACOSX/data/train_images/._2384.jpg
#   inflating: data/train_images/4939.jpg
#   inflating: __MACOSX/data/train_images/._4939.jpg
#   inflating: data/train_images/2390.jpg
#   inflating: __MACOSX/data/train_images/._2390.jpg
#   inflating: data/train_images/1699.jpg
#   inflating: __MACOSX/data/train_images/._1699.jpg
#   inflating: data/train_images/1841.jpg
#   inflating: __MACOSX/data/train_images/._1841.jpg
#   inflating: data/train_images/5399.jpg
#   inflating: __MACOSX/data/train_images/._5399.jpg
#   inflating: data/train_images/3930.jpg
#   inflating: __MACOSX/data/train_images/._3930.jpg
#   inflating: data/train_images/4087.jpg
#   inflating: __MACOSX/data/train_images/._4087.jpg
#   inflating: data/train_images/443.jpg
#   inflating: __MACOSX/data/train_images/._443.jpg
#   inflating: data/train_images/3918.jpg
#   inflating: __MACOSX/data/train_images/._3918.jpg
#   inflating: data/train_images/4911.jpg
#   inflating: __MACOSX/data/train_images/._4911.jpg
#   inflating: data/train_images/325.jpg
#   inflating: __MACOSX/data/train_images/._325.jpg
#   inflating: data/train_images/1869.jpg
#   inflating: __MACOSX/data/train_images/._1869.jpg
#   inflating: data/train_images/331.jpg
#   inflating: __MACOSX/data/train_images/._331.jpg
#   inflating: data/train_images/4905.jpg
#   inflating: __MACOSX/data/train_images/._4905.jpg
#   inflating: data/train_images/457.jpg
#   inflating: __MACOSX/data/train_images/._457.jpg
#   inflating: data/train_images/1128.jpg
#   inflating: __MACOSX/data/train_images/._1128.jpg
#   inflating: data/train_images/4050.jpg
#   inflating: __MACOSX/data/train_images/._4050.jpg
#   inflating: data/train_images/2421.jpg
#   inflating: __MACOSX/data/train_images/._2421.jpg
#   inflating: data/train_images/2347.jpg
#   inflating: __MACOSX/data/train_images/._2347.jpg
#   inflating: data/train_images/5428.jpg
#   inflating: __MACOSX/data/train_images/._5428.jpg
#   inflating: data/train_images/4736.jpg
#   inflating: __MACOSX/data/train_images/._4736.jpg
#   inflating: data/train_images/3059.jpg
#   inflating: __MACOSX/data/train_images/._3059.jpg
#   inflating: data/train_images/1896.jpg
#   inflating: __MACOSX/data/train_images/._1896.jpg
#   inflating: data/train_images/6121.jpg
#   inflating: __MACOSX/data/train_images/._6121.jpg
#   inflating: data/train_images/1882.jpg
#   inflating: __MACOSX/data/train_images/._1882.jpg
#   inflating: data/train_images/6135.jpg
#   inflating: __MACOSX/data/train_images/._6135.jpg
#   inflating: data/train_images/2353.jpg
#   inflating: __MACOSX/data/train_images/._2353.jpg
#   inflating: data/train_images/4722.jpg
#   inflating: __MACOSX/data/train_images/._4722.jpg
#   inflating: data/train_images/4044.jpg
#   inflating: __MACOSX/data/train_images/._4044.jpg
#   inflating: data/train_images/2435.jpg
#   inflating: __MACOSX/data/train_images/._2435.jpg
#   inflating: data/train_images/3703.jpg
#   inflating: __MACOSX/data/train_images/._3703.jpg
#   inflating: data/train_images/5372.jpg
#   inflating: __MACOSX/data/train_images/._5372.jpg
#   inflating: data/train_images/480.jpg
#   inflating: __MACOSX/data/train_images/._480.jpg
#   inflating: data/train_images/1114.jpg
#   inflating: __MACOSX/data/train_images/._1114.jpg
#   inflating: data/train_images/1672.jpg
#   inflating: __MACOSX/data/train_images/._1672.jpg
#   inflating: data/train_images/5414.jpg
#   inflating: __MACOSX/data/train_images/._5414.jpg
#   inflating: data/train_images/3065.jpg
#   inflating: __MACOSX/data/train_images/._3065.jpg
#   inflating: data/train_images/5400.jpg
#   inflating: __MACOSX/data/train_images/._5400.jpg
#   inflating: data/train_images/3071.jpg
#   inflating: __MACOSX/data/train_images/._3071.jpg
#   inflating: data/train_images/6109.jpg
#   inflating: __MACOSX/data/train_images/._6109.jpg
#   inflating: data/train_images/1666.jpg
#   inflating: __MACOSX/data/train_images/._1666.jpg
#   inflating: data/train_images/1100.jpg
#   inflating: __MACOSX/data/train_images/._1100.jpg
#   inflating: data/train_images/494.jpg
#   inflating: __MACOSX/data/train_images/._494.jpg
#   inflating: data/train_images/3717.jpg
#   inflating: __MACOSX/data/train_images/._3717.jpg
#   inflating: data/train_images/4078.jpg
#   inflating: __MACOSX/data/train_images/._4078.jpg
#   inflating: data/train_images/5366.jpg
#   inflating: __MACOSX/data/train_images/._5366.jpg
#   inflating: data/train_images/2409.jpg
#   inflating: __MACOSX/data/train_images/._2409.jpg
#   inflating: data/train_images/2186.jpg
#   inflating: __MACOSX/data/train_images/._2186.jpg
#   inflating: data/train_images/3298.jpg
#   inflating: __MACOSX/data/train_images/._3298.jpg
#   inflating: data/train_images/5831.jpg
#   inflating: __MACOSX/data/train_images/._5831.jpg
#   inflating: data/train_images/2838.jpg
#   inflating: __MACOSX/data/train_images/._2838.jpg
#   inflating: data/train_images/4291.jpg
#   inflating: __MACOSX/data/train_images/._4291.jpg
#   inflating: data/train_images/4285.jpg
#   inflating: __MACOSX/data/train_images/._4285.jpg
#   inflating: data/train_images/669.jpg
#   inflating: __MACOSX/data/train_images/._669.jpg
#   inflating: data/train_images/2192.jpg
#   inflating: __MACOSX/data/train_images/._2192.jpg
#   inflating: data/train_images/5825.jpg
#   inflating: __MACOSX/data/train_images/._5825.jpg
#   inflating: data/train_images/127.jpg
#   inflating: __MACOSX/data/train_images/._127.jpg
#   inflating: data/train_images/2804.jpg
#   inflating: __MACOSX/data/train_images/._2804.jpg
#   inflating: data/train_images/641.jpg
#   inflating: __MACOSX/data/train_images/._641.jpg
#   inflating: data/train_images/899.jpg
#   inflating: __MACOSX/data/train_images/._899.jpg
#   inflating: data/train_images/655.jpg
#   inflating: __MACOSX/data/train_images/._655.jpg
#   inflating: data/train_images/2810.jpg
#   inflating: __MACOSX/data/train_images/._2810.jpg
#   inflating: data/train_images/5819.jpg
#   inflating: __MACOSX/data/train_images/._5819.jpg
#   inflating: data/train_images/133.jpg
#   inflating: __MACOSX/data/train_images/._133.jpg
#   inflating: data/train_images/4534.jpg
#   inflating: __MACOSX/data/train_images/._4534.jpg
#   inflating: data/train_images/2145.jpg
#   inflating: __MACOSX/data/train_images/._2145.jpg
#   inflating: data/train_images/2623.jpg
#   inflating: __MACOSX/data/train_images/._2623.jpg
#   inflating: data/train_images/4252.jpg
#   inflating: __MACOSX/data/train_images/._4252.jpg
#   inflating: data/train_images/866.jpg
#   inflating: __MACOSX/data/train_images/._866.jpg
#   inflating: data/train_images/26.jpg
#   inflating: __MACOSX/data/train_images/._26.jpg
#   inflating: data/train_images/872.jpg
#   inflating: __MACOSX/data/train_images/._872.jpg
#   inflating: data/train_images/32.jpg
#   inflating: __MACOSX/data/train_images/._32.jpg
#   inflating: data/train_images/2637.jpg
#   inflating: __MACOSX/data/train_images/._2637.jpg
#   inflating: data/train_images/5158.jpg
#   inflating: __MACOSX/data/train_images/._5158.jpg
#   inflating: data/train_images/4246.jpg
#   inflating: __MACOSX/data/train_images/._4246.jpg
#   inflating: data/train_images/3529.jpg
#   inflating: __MACOSX/data/train_images/._3529.jpg
#   inflating: data/train_images/4520.jpg
#   inflating: __MACOSX/data/train_images/._4520.jpg
#   inflating: data/train_images/2151.jpg
#   inflating: __MACOSX/data/train_images/._2151.jpg
#   inflating: data/train_images/1458.jpg
#   inflating: __MACOSX/data/train_images/._1458.jpg
#   inflating: data/train_images/3267.jpg
#   inflating: __MACOSX/data/train_images/._3267.jpg
#   inflating: data/train_images/4508.jpg
#   inflating: __MACOSX/data/train_images/._4508.jpg
#   inflating: data/train_images/5616.jpg
#   inflating: __MACOSX/data/train_images/._5616.jpg
#   inflating: data/train_images/2179.jpg
#   inflating: __MACOSX/data/train_images/._2179.jpg
#   inflating: data/train_images/1470.jpg
#   inflating: __MACOSX/data/train_images/._1470.jpg
#   inflating: data/train_images/1316.jpg
#   inflating: __MACOSX/data/train_images/._1316.jpg
#   inflating: data/train_images/682.jpg
# ...
#   inflating: data/train_images/5716.jpg
#   inflating: __MACOSX/data/train_images/._5716.jpg
#   inflating: data/train_images/4408.jpg
#   inflating: __MACOSX/data/train_images/._4408.jpg
#   inflating: data/train_images/3367.jpg
#   inflating: __MACOSX/data/train_images/._3367.jpg
#   inflating: data/train_images/1570.jpg
#   inflating: __MACOSX/data/train_images/._1570.jpg
#   inflating: data/train_images/1564.jpg
#   inflating: __MACOSX/data/train_images/._1564.jpg
#   inflating: data/train_images/5702.jpg
#   inflating: __MACOSX/data/train_images/._5702.jpg
#   inflating: data/train_images/3373.jpg
#   inflating: __MACOSX/data/train_images/._3373.jpg
#   inflating: data/train_images/3415.jpg
#   inflating: __MACOSX/data/train_images/._3415.jpg
#   inflating: data/train_images/5064.jpg
#   inflating: __MACOSX/data/train_images/._5064.jpg
#   inflating: data/train_images/1202.jpg
#   inflating: __MACOSX/data/train_images/._1202.jpg
#   inflating: data/train_images/796.jpg
#   inflating: __MACOSX/data/train_images/._796.jpg
#   inflating: data/train_images/1955.jpg
#   inflating: __MACOSX/data/train_images/._1955.jpg
#   inflating: data/train_images/219.jpg
#   inflating: __MACOSX/data/train_images/._219.jpg
#   inflating: data/train_images/2284.jpg
#   inflating: __MACOSX/data/train_images/._2284.jpg
#   inflating: data/train_images/4193.jpg
#   inflating: __MACOSX/data/train_images/._4193.jpg
#   inflating: data/train_images/3824.jpg
#   inflating: __MACOSX/data/train_images/._3824.jpg
#   inflating: data/train_images/4187.jpg
#   inflating: __MACOSX/data/train_images/._4187.jpg
#   inflating: data/train_images/5299.jpg
#   inflating: __MACOSX/data/train_images/._5299.jpg
#   inflating: data/train_images/3830.jpg
#   inflating: __MACOSX/data/train_images/._3830.jpg
#   inflating: data/train_images/4839.jpg
#   inflating: __MACOSX/data/train_images/._4839.jpg
#   inflating: data/train_images/2290.jpg
#   inflating: __MACOSX/data/train_images/._2290.jpg
#   inflating: data/train_images/1941.jpg
#   inflating: __MACOSX/data/train_images/._1941.jpg
#   inflating: data/train_images/1799.jpg
#   inflating: __MACOSX/data/train_images/._1799.jpg
#   inflating: data/train_images/4811.jpg
#   inflating: __MACOSX/data/train_images/._4811.jpg
#   inflating: data/train_images/1969.jpg
#   inflating: __MACOSX/data/train_images/._1969.jpg
#   inflating: data/train_images/225.jpg
#   inflating: __MACOSX/data/train_images/._225.jpg
#   inflating: data/train_images/543.jpg
#   inflating: __MACOSX/data/train_images/._543.jpg
#   inflating: data/train_images/3818.jpg
#   inflating: __MACOSX/data/train_images/._3818.jpg
#   inflating: data/train_images/557.jpg
#   inflating: __MACOSX/data/train_images/._557.jpg
#   inflating: data/train_images/231.jpg
#   inflating: __MACOSX/data/train_images/._231.jpg
#   inflating: data/train_images/4805.jpg
#   inflating: __MACOSX/data/train_images/._4805.jpg
#   inflating: data/train_images/3159.jpg
#   inflating: __MACOSX/data/train_images/._3159.jpg
#   inflating: data/train_images/4636.jpg
#   inflating: __MACOSX/data/train_images/._4636.jpg
#   inflating: data/train_images/5528.jpg
#   inflating: __MACOSX/data/train_images/._5528.jpg
#   inflating: data/train_images/2247.jpg
#   inflating: __MACOSX/data/train_images/._2247.jpg
#   inflating: data/train_images/6021.jpg
#   inflating: __MACOSX/data/train_images/._6021.jpg
#   inflating: data/train_images/1996.jpg
#   inflating: __MACOSX/data/train_images/._1996.jpg
#   inflating: data/train_images/1028.jpg
#   inflating: __MACOSX/data/train_images/._1028.jpg
#   inflating: data/train_images/2521.jpg
#   inflating: __MACOSX/data/train_images/._2521.jpg
#   inflating: data/train_images/4150.jpg
#   inflating: __MACOSX/data/train_images/._4150.jpg
#   inflating: data/train_images/2535.jpg
#   inflating: __MACOSX/data/train_images/._2535.jpg
#   inflating: data/train_images/4144.jpg
#   inflating: __MACOSX/data/train_images/._4144.jpg
#   inflating: data/train_images/6035.jpg
#   inflating: __MACOSX/data/train_images/._6035.jpg
#   inflating: data/train_images/1982.jpg
#   inflating: __MACOSX/data/train_images/._1982.jpg
#   inflating: data/train_images/4622.jpg
#   inflating: __MACOSX/data/train_images/._4622.jpg
#   inflating: data/train_images/2253.jpg
#   inflating: __MACOSX/data/train_images/._2253.jpg
#   inflating: data/train_images/1772.jpg
#   inflating: __MACOSX/data/train_images/._1772.jpg
#   inflating: data/train_images/3165.jpg
#   inflating: __MACOSX/data/train_images/._3165.jpg
#   inflating: data/train_images/5514.jpg
#   inflating: __MACOSX/data/train_images/._5514.jpg
#   inflating: data/train_images/5272.jpg
#   inflating: __MACOSX/data/train_images/._5272.jpg
#   inflating: data/train_images/3603.jpg
#   inflating: __MACOSX/data/train_images/._3603.jpg
#   inflating: data/train_images/1014.jpg
#   inflating: __MACOSX/data/train_images/._1014.jpg
#   inflating: data/train_images/580.jpg
#   inflating: __MACOSX/data/train_images/._580.jpg
#   inflating: data/train_images/594.jpg
#   inflating: __MACOSX/data/train_images/._594.jpg
#   inflating: data/train_images/1000.jpg
#   inflating: __MACOSX/data/train_images/._1000.jpg
#   inflating: data/train_images/2509.jpg
#   inflating: __MACOSX/data/train_images/._2509.jpg
#   inflating: data/train_images/5266.jpg
#   inflating: __MACOSX/data/train_images/._5266.jpg
#   inflating: data/train_images/4178.jpg
#   inflating: __MACOSX/data/train_images/._4178.jpg
#   inflating: data/train_images/3617.jpg
#   inflating: __MACOSX/data/train_images/._3617.jpg
#   inflating: data/train_images/3171.jpg
#   inflating: __MACOSX/data/train_images/._3171.jpg
#   inflating: data/train_images/5500.jpg
#   inflating: __MACOSX/data/train_images/._5500.jpg
#   inflating: data/train_images/1766.jpg
#   inflating: __MACOSX/data/train_images/._1766.jpg
#   inflating: data/train_images/6009.jpg
#   inflating: __MACOSX/data/train_images/._6009.jpg
#   inflating: data/train_images/6196.jpg
#   inflating: __MACOSX/data/train_images/._6196.jpg
#   inflating: data/train_images/1821.jpg
#   inflating: __MACOSX/data/train_images/._1821.jpg
#   inflating: data/train_images/4781.jpg
#   inflating: __MACOSX/data/train_images/._4781.jpg
#   inflating: data/train_images/4959.jpg
#   inflating: __MACOSX/data/train_images/._4959.jpg
#   inflating: data/train_images/3950.jpg
#   inflating: __MACOSX/data/train_images/._3950.jpg
#   inflating: data/train_images/2496.jpg
#   inflating: __MACOSX/data/train_images/._2496.jpg
#   inflating: data/train_images/3788.jpg
#   inflating: __MACOSX/data/train_images/._3788.jpg
#   inflating: data/train_images/3944.jpg
#   inflating: __MACOSX/data/train_images/._3944.jpg
#   inflating: data/train_images/2482.jpg
#   inflating: __MACOSX/data/train_images/._2482.jpg
#   inflating: data/train_images/4795.jpg
#   inflating: __MACOSX/data/train_images/._4795.jpg
#   inflating: data/train_images/6182.jpg
#   inflating: __MACOSX/data/train_images/._6182.jpg
#   inflating: data/train_images/379.jpg
#   inflating: __MACOSX/data/train_images/._379.jpg
#   inflating: data/train_images/1835.jpg
#   inflating: __MACOSX/data/train_images/._1835.jpg
#   inflating: data/train_images/4965.jpg
#   inflating: __MACOSX/data/train_images/._4965.jpg
#   inflating: data/train_images/351.jpg
#   inflating: __MACOSX/data/train_images/._351.jpg
#   inflating: data/train_images/437.jpg
#   inflating: __MACOSX/data/train_images/._437.jpg
#   inflating: data/train_images/3978.jpg
#   inflating: __MACOSX/data/train_images/._3978.jpg
#   inflating: data/train_images/423.jpg
#   inflating: __MACOSX/data/train_images/._423.jpg
#   inflating: data/train_images/345.jpg
#   inflating: __MACOSX/data/train_images/._345.jpg
#   inflating: data/train_images/1809.jpg
#   inflating: __MACOSX/data/train_images/._1809.jpg
#   inflating: data/train_images/4971.jpg
#   inflating: __MACOSX/data/train_images/._4971.jpg
#   inflating: data/train_images/2333.jpg
#   inflating: __MACOSX/data/train_images/._2333.jpg
#   inflating: data/train_images/4742.jpg
#   inflating: __MACOSX/data/train_images/._4742.jpg
#   inflating: data/train_images/6155.jpg
#   inflating: __MACOSX/data/train_images/._6155.jpg
#   inflating: data/train_images/4024.jpg
#   inflating: __MACOSX/data/train_images/._4024.jpg
#   inflating: data/train_images/3993.jpg
#   inflating: __MACOSX/data/train_images/._3993.jpg
#   inflating: data/train_images/2455.jpg
#   inflating: __MACOSX/data/train_images/._2455.jpg
#   inflating: data/train_images/4030.jpg
#   inflating: __MACOSX/data/train_images/._4030.jpg
#   inflating: data/train_images/3987.jpg
#   inflating: __MACOSX/data/train_images/._3987.jpg
#   inflating: data/train_images/2441.jpg
#   inflating: __MACOSX/data/train_images/._2441.jpg
#   inflating: data/train_images/1148.jpg
#   inflating: __MACOSX/data/train_images/._1148.jpg
#   inflating: data/train_images/6141.jpg
#   inflating: __MACOSX/data/train_images/._6141.jpg
#   inflating: data/train_images/2327.jpg
#   inflating: __MACOSX/data/train_images/._2327.jpg
#   inflating: data/train_images/5448.jpg
#   inflating: __MACOSX/data/train_images/._5448.jpg
#   inflating: data/train_images/4756.jpg
#   inflating: __MACOSX/data/train_images/._4756.jpg
#   inflating: data/train_images/3039.jpg
#   inflating: __MACOSX/data/train_images/._3039.jpg
#   inflating: data/train_images/6169.jpg
#   inflating: __MACOSX/data/train_images/._6169.jpg
#   inflating: data/train_images/1606.jpg
#   inflating: __MACOSX/data/train_images/._1606.jpg
#   inflating: data/train_images/392.jpg
#   inflating: __MACOSX/data/train_images/._392.jpg
#   inflating: data/train_images/5460.jpg
#   inflating: __MACOSX/data/train_images/._5460.jpg
#   inflating: data/train_images/3011.jpg
#   inflating: __MACOSX/data/train_images/._3011.jpg
#   inflating: data/train_images/3777.jpg
#   inflating: __MACOSX/data/train_images/._3777.jpg
#   inflating: data/train_images/4018.jpg
#   inflating: __MACOSX/data/train_images/._4018.jpg
#   inflating: data/train_images/5306.jpg
#   inflating: __MACOSX/data/train_images/._5306.jpg
#   inflating: data/train_images/2469.jpg
#   inflating: __MACOSX/data/train_images/._2469.jpg
#   inflating: data/train_images/1160.jpg
#   inflating: __MACOSX/data/train_images/._1160.jpg
#   inflating: data/train_images/1174.jpg
#   inflating: __MACOSX/data/train_images/._1174.jpg
#   inflating: data/train_images/3763.jpg
#   inflating: __MACOSX/data/train_images/._3763.jpg
#   inflating: data/train_images/5312.jpg
#   inflating: __MACOSX/data/train_images/._5312.jpg
#   inflating: data/train_images/5474.jpg
#   inflating: __MACOSX/data/train_images/._5474.jpg
#   inflating: data/train_images/3005.jpg
#   inflating: __MACOSX/data/train_images/._3005.jpg
#   inflating: data/train_images/386.jpg
#   inflating: __MACOSX/data/train_images/._386.jpg
#   inflating: data/train_images/1612.jpg
#   inflating: __MACOSX/data/train_images/._1612.jpg
#   inflating: data/train_images/91.jpg
#   inflating: __MACOSX/data/train_images/._91.jpg
#   inflating: data/train_images/609.jpg
#   inflating: __MACOSX/data/train_images/._609.jpg
#   inflating: data/train_images/2694.jpg
#   inflating: __MACOSX/data/train_images/._2694.jpg
#   inflating: data/train_images/5845.jpg
#   inflating: __MACOSX/data/train_images/._5845.jpg
#   inflating: data/train_images/4583.jpg
#   inflating: __MACOSX/data/train_images/._4583.jpg
#   inflating: data/train_images/5689.jpg
#   inflating: __MACOSX/data/train_images/._5689.jpg
#   inflating: data/train_images/5851.jpg
#   inflating: __MACOSX/data/train_images/._5851.jpg
#   inflating: data/train_images/4597.jpg
#   inflating: __MACOSX/data/train_images/._4597.jpg
#   inflating: data/train_images/2858.jpg
#   inflating: __MACOSX/data/train_images/._2858.jpg
#   inflating: data/train_images/2680.jpg
#   inflating: __MACOSX/data/train_images/._2680.jpg
#   inflating: data/train_images/85.jpg
#   inflating: __MACOSX/data/train_images/._85.jpg
#   inflating: data/train_images/1389.jpg
#   inflating: __MACOSX/data/train_images/._1389.jpg
#   inflating: data/train_images/2870.jpg
#   inflating: __MACOSX/data/train_images/._2870.jpg
#   inflating: data/train_images/635.jpg
#   inflating: __MACOSX/data/train_images/._635.jpg
#   inflating: data/train_images/153.jpg
#   inflating: __MACOSX/data/train_images/._153.jpg
#   inflating: data/train_images/5879.jpg
#   inflating: __MACOSX/data/train_images/._5879.jpg
#   inflating: data/train_images/147.jpg
#   inflating: __MACOSX/data/train_images/._147.jpg
#   inflating: data/train_images/621.jpg
#   inflating: __MACOSX/data/train_images/._621.jpg
#   inflating: data/train_images/2864.jpg
#   inflating: __MACOSX/data/train_images/._2864.jpg
#   inflating: data/train_images/2657.jpg
#   inflating: __MACOSX/data/train_images/._2657.jpg
#   inflating: data/train_images/5138.jpg
#   inflating: __MACOSX/data/train_images/._5138.jpg
#   inflating: data/train_images/4226.jpg
#   inflating: __MACOSX/data/train_images/._4226.jpg
#   inflating: data/train_images/3549.jpg
#   inflating: __MACOSX/data/train_images/._3549.jpg
#   inflating: data/train_images/812.jpg
#   inflating: __MACOSX/data/train_images/._812.jpg
#   inflating: data/train_images/52.jpg
#   inflating: __MACOSX/data/train_images/._52.jpg
#   inflating: data/train_images/1438.jpg
#   inflating: __MACOSX/data/train_images/._1438.jpg
#   inflating: data/train_images/5886.jpg
#   inflating: __MACOSX/data/train_images/._5886.jpg
#   inflating: data/train_images/0.jpg
#   inflating: __MACOSX/data/train_images/._0.jpg
#   inflating: data/train_images/4540.jpg
#   inflating: __MACOSX/data/train_images/._4540.jpg
#   inflating: data/train_images/2131.jpg
#   inflating: __MACOSX/data/train_images/._2131.jpg
#   inflating: data/train_images/5892.jpg
#   inflating: __MACOSX/data/train_images/._5892.jpg
#   inflating: data/train_images/4554.jpg
#   inflating: __MACOSX/data/train_images/._4554.jpg
#   inflating: data/train_images/2125.jpg
#   inflating: __MACOSX/data/train_images/._2125.jpg
#   inflating: data/train_images/806.jpg
#   inflating: __MACOSX/data/train_images/._806.jpg
#   inflating: data/train_images/46.jpg
#   inflating: __MACOSX/data/train_images/._46.jpg
#   inflating: data/train_images/2643.jpg
#   inflating: __MACOSX/data/train_images/._2643.jpg
#   inflating: data/train_images/4232.jpg
#   inflating: __MACOSX/data/train_images/._4232.jpg
#   inflating: data/train_images/1362.jpg
#   inflating: __MACOSX/data/train_images/._1362.jpg
#   inflating: data/train_images/5104.jpg
#   inflating: __MACOSX/data/train_images/._5104.jpg
#   inflating: data/train_images/3575.jpg
#   inflating: __MACOSX/data/train_images/._3575.jpg
#   inflating: data/train_images/3213.jpg
#   inflating: __MACOSX/data/train_images/._3213.jpg
#   inflating: data/train_images/5662.jpg
#   inflating: __MACOSX/data/train_images/._5662.jpg
#   inflating: data/train_images/190.jpg
#   inflating: __MACOSX/data/train_images/._190.jpg
#   inflating: data/train_images/1404.jpg
#   inflating: __MACOSX/data/train_images/._1404.jpg
#   inflating: data/train_images/1410.jpg
#   inflating: __MACOSX/data/train_images/._1410.jpg
#   inflating: data/train_images/184.jpg
#   inflating: __MACOSX/data/train_images/._184.jpg
#   inflating: data/train_images/3207.jpg
#   inflating: __MACOSX/data/train_images/._3207.jpg
#   inflating: data/train_images/4568.jpg
#   inflating: __MACOSX/data/train_images/._4568.jpg
#   inflating: data/train_images/5676.jpg
#   inflating: __MACOSX/data/train_images/._5676.jpg
#   inflating: data/train_images/2119.jpg
#   inflating: __MACOSX/data/train_images/._2119.jpg
#   inflating: data/train_images/5110.jpg
#   inflating: __MACOSX/data/train_images/._5110.jpg
#   inflating: data/train_images/3561.jpg
#   inflating: __MACOSX/data/train_images/._3561.jpg
#   inflating: data/train_images/1376.jpg
#   inflating: __MACOSX/data/train_images/._1376.jpg

# %%
# Generate novel training data
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to("cuda")  # Use GPU for speed

novel_super_class_count = 1000
novel_sub_class_count = 20

# Create a prompt that excludes dogs, birds, and reptiles
for i in range(int(novel_super_class_count/10)):
  prompt = f"batch {i}: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off"
  negative_prompt = "dog, bird, reptile, no animal"
  print(prompt)
  # Generate the image
  images = pipe(
      prompt=prompt,
      negative_prompt=negative_prompt,
      # height=64,
      # width=64,
      num_inference_steps=30,
      guidance_scale=12,
      height=512,
      width=512,
      num_images_per_prompt=10
      ).images
  for j in range(10):
    image = images[j]
  # Save the image
    image.save(f"data/train_images/{j+i*10+6288}.jpg")

existing_subclasses = pd.read_csv("data/subclass_mapping.csv")["class"].tolist()
subclass_negative_prompt = f"{', '.join(existing_subclasses)}, dog, reptile, no animal, low quality, blurry"

for i, super_class in enumerate(["bird", "dog", "reptile"]):
  for m in range(int(novel_sub_class_count/10)):
    subclass_prompt = f"batch {m}: nature photograph of a {super_class}, centered composition, photorealistic, the {super_class} is more than 50% of the image, the {super_class} is fully visible within frame and not cut off"
        # Generate the image
    images = pipe(
            prompt=subclass_prompt,
            negative_prompt=subclass_negative_prompt,
            num_inference_steps=30,
            guidance_scale=12,
            height=512,
            width=512,
            num_images_per_prompt=10
        ).images

    for j in range(10):
        image = images[j]
        # Save with continuing index from previous loop
        image.save(f"data/train_images/{j+m*10+novel_sub_class_count*i+6288+novel_super_class_count}.jpg")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# batch 0: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 1: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 2: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 3: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 4: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 5: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 6: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 7: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 8: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 9: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 10: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 11: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 12: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 13: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 14: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 15: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 16: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 17: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 18: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 19: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 20: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 21: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 22: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 23: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 24: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 25: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 26: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 27: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 28: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 29: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 30: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 31: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 32: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 33: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 34: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 35: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 36: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 37: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 38: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 39: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 40: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 41: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 42: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 43: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 44: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 45: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 46: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 47: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 48: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 49: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 50: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 51: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 52: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 53: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 54: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 55: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 56: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 57: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 58: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 59: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 60: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 61: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 62: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 63: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 64: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 65: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 66: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 67: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 68: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 69: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 70: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 71: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# batch 72: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 73: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 74: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 75: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 76: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 77: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 78: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 79: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 80: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 81: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 82: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 83: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 84: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 85: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 86: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 87: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 88: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 89: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 90: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 91: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 92: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 93: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 94: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 95: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 96: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 97: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 98: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
# batch 99: nature photograph of a sea animal, like fish, shark, etc, centered composition, photorealistic, 8k, the animal is fully visible within frame and not cut off
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# Create Dataset class for multilabel classification
class MultiClassImageDataset(Dataset):
    def __init__(self, ann_df, super_map_df, sub_map_df, img_dir, transform=None):
        self.ann_df = ann_df
        self.super_map_df = super_map_df
        self.sub_map_df = sub_map_df
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.ann_df)

    def __getitem__(self, idx):
        img_name = self.ann_df['image'][idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        super_idx = self.ann_df['superclass_index'][idx]
        super_label = self.super_map_df['class'][super_idx]

        sub_idx = self.ann_df['subclass_index'][idx]
        sub_label = self.sub_map_df['class'][sub_idx]

        if self.transform:
            image = self.transform(image)

        return image, super_idx, super_label, sub_idx, sub_label

class MultiClassImageTestDataset(Dataset):
    def __init__(self, super_map_df, sub_map_df, img_dir, transform=None):
        self.super_map_df = super_map_df
        self.sub_map_df = sub_map_df
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self): # Count files in img_dir
        return len([fname for fname in os.listdir(self.img_dir)])

    def __getitem__(self, idx):
        img_name = str(idx) + '.jpg'
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, img_name

# %%
def calculate_weights(train_ann_df):
    # Assuming you have the counts for both superclass and subclass
    superclass_counts = train_ann_df['superclass_index'].value_counts().sort_index()
    subclass_counts = train_ann_df['subclass_index'].value_counts().sort_index()

    # Calculate weights for both
    superclass_weights = 1.0 / superclass_counts
    superclass_weights = superclass_weights / superclass_weights.sum()
    superclass_weights = torch.tensor(superclass_weights.values, dtype=torch.float32)

    subclass_weights = 1.0 / subclass_counts
    subclass_weights = subclass_weights / subclass_weights.sum()
    subclass_weights = torch.tensor(subclass_weights.values, dtype=torch.float32)

    # superclass_weights = torch.cat([superclass_weights, torch.tensor([0.0], dtype=torch.float32)])
    # subclass_weights = torch.cat([subclass_weights, torch.tensor([0.0], dtype=torch.float32)])

    print(superclass_weights)
    print(subclass_weights)
    return superclass_weights, subclass_weights

# %%
train_ann_df = pd.read_csv('data/train_data.csv')

# Add new rows with superclass 3 and subclass 87
new_rows_super = pd.DataFrame({
    'image': [f"{i}.jpg" for i in range(6288, 6288+novel_super_class_count)],  # Generate image paths from 6288.JPG to 6387.JPG
    'superclass_index': [3] * novel_super_class_count,
    'subclass_index': [87] * novel_super_class_count
})
train_ann_df = pd.concat([train_ann_df, new_rows_super], ignore_index=True)
new_rows_bird = pd.DataFrame({
    'image': [f"{i}.jpg" for i in range(6288+novel_super_class_count, 6288+novel_super_class_count+novel_sub_class_count)],  # Generate image paths from 6288.JPG to 6387.JPG
    'superclass_index': [0] * novel_sub_class_count,
    'subclass_index': [87] * novel_sub_class_count
})
train_ann_df = pd.concat([train_ann_df, new_rows_bird], ignore_index=True)
new_rows_dog = pd.DataFrame({
    'image': [f"{i}.jpg" for i in range(6288+novel_super_class_count+novel_sub_class_count, 6288+novel_super_class_count+novel_sub_class_count*2)],  # Generate image paths from 6288.JPG to 6387.JPG
    'superclass_index': [1] * novel_sub_class_count,
    'subclass_index': [87] * novel_sub_class_count
})
train_ann_df = pd.concat([train_ann_df, new_rows_dog], ignore_index=True)
new_rows_reptile = pd.DataFrame({
    'image': [f"{i}.jpg" for i in range(6288+novel_super_class_count+novel_sub_class_count*2, 6288+novel_super_class_count+novel_sub_class_count*3)],  # Generate image paths from 6288.JPG to 6387.JPG
    'superclass_index': [2] * novel_sub_class_count,
    'subclass_index': [87] * novel_sub_class_count
})
train_ann_df = pd.concat([train_ann_df, new_rows_reptile], ignore_index=True)
# print(train_ann_df)

# test_ann_df = pd.read_csv('data/test_data.csv')
super_map_df = pd.read_csv('data/superclass_mapping.csv')
sub_map_df = pd.read_csv('data/subclass_mapping.csv')

train_img_dir = 'data/train_images'
test_img_dir = 'data/test_images'

augmentation_setups = {
    "baseline": transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ]),
    "autoaugment": transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.AutoAugment(policy=AutoAugmentPolicy.IMAGENET),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ]),
    "manual_combo": transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomRotation(degrees=15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225]),
    ])
}

# image_preprocessing = transforms.Compose([
#     transforms.Resize((384, 384)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
# ])

superclass_weights, subclass_weights = calculate_weights(train_ann_df)

# Create train and val split
train_dataset = MultiClassImageDataset(train_ann_df, super_map_df, sub_map_df, train_img_dir, transform=augmentation_setups["manual_combo"])
train_dataset, val_dataset = random_split(train_dataset, [0.9, 0.1])

# Create test dataset
test_dataset = MultiClassImageTestDataset(super_map_df, sub_map_df, test_img_dir, transform=augmentation_setups["baseline"])

# Create dataloaders
batch_size = 32
train_loader = DataLoader(train_dataset,
                          batch_size=batch_size,
                          shuffle=True)

val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=1,
                         shuffle=False)
# Out:
# tensor([0.2200, 0.1955, 0.1733, 0.4113])
# tensor([0.0150, 0.0074, 0.0150, 0.0147, 0.0074, 0.0147, 0.0074, 0.0074, 0.0147,
#         0.0150, 0.0150, 0.0147, 0.0150, 0.0150, 0.0147, 0.0150, 0.0147, 0.0150,
#         0.0074, 0.0147, 0.0147, 0.0074, 0.0074, 0.0150, 0.0074, 0.0150, 0.0147,
#         0.0074, 0.0074, 0.0073, 0.0074, 0.0074, 0.0150, 0.0144, 0.0150, 0.0072,
#         0.0074, 0.0074, 0.0150, 0.0150, 0.0147, 0.0147, 0.0147, 0.0074, 0.0074,
#         0.0150, 0.0074, 0.0074, 0.0150, 0.0074, 0.0074, 0.0147, 0.0074, 0.0150,
#         0.0150, 0.0147, 0.0147, 0.0073, 0.0074, 0.0147, 0.0147, 0.0073, 0.0074,
#         0.0072, 0.0074, 0.0074, 0.0072, 0.0150, 0.0150, 0.0073, 0.0074, 0.0074,
#         0.0074, 0.0147, 0.0150, 0.0074, 0.0074, 0.0150, 0.0147, 0.0150, 0.0147,
#         0.0073, 0.0147, 0.0147, 0.0074, 0.0150, 0.0147, 0.0007])

# %%
from re import sub
class EfficientNetV2MultiHead(nn.Module):
    def __init__(self, num_super=4, num_sub=88, pretrained=True):
        super().__init__()
        weights = EfficientNet_V2_S_Weights.DEFAULT if pretrained else None
        pre_trained = efficientnet_v2_s(weights=weights)
        self.backbone = pre_trained.features
        self.avgpool = pre_trained.avgpool
        self.fc = nn.Linear(1280, 256)
        self.dropout = nn.Dropout(0.3)
        self.classifer_super = nn.Linear(256, num_super)
        self.classifer_sub = nn.Linear(256 + num_super, num_sub)

    def forward(self, x):
        x = self.backbone(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc(x))
        x = self.dropout(x)
        # print(x.size())
        super_out = self.classifer_super(x)
        # print(super_out)

        super_probs = F.softmax(super_out, dim=1)
        x_with_super = torch.cat([x, super_out], dim=1)

        sub_out = self.classifer_sub(x_with_super)
        sub_probs = F.softmax(sub_out, dim=1)
        return super_out, sub_out

class Trainer():
    def __init__(self, model, super_criterion, sub_criterion, optimizer, train_loader, val_loader, test_loader=None, device='cuda'):
        self.model = model
        self.super_criterion = super_criterion
        self.sub_criterion = sub_criterion
        self.optimizer = optimizer
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.test_loader = test_loader

    def train_epoch(self):
        running_loss = 0.0
        for i, data in enumerate(self.train_loader):
            inputs, super_labels, sub_labels = data[0].to(device), data[1].to(device), data[3].to(device)

            self.optimizer.zero_grad()
            super_outputs, sub_outputs = self.model(inputs)
            loss = self.super_criterion(super_outputs, super_labels) + self.sub_criterion(sub_outputs, sub_labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f'Training loss: {running_loss/i:.3f}')

    def validate_epoch(self):
        super_correct = 0
        sub_correct = 0
        total = 0
        running_loss = 0.0
        running_super_loss = 0.0
        running_sub_loss = 0.0
        with torch.no_grad():
            for i, data in enumerate(self.val_loader):
                inputs, super_labels, sub_labels = data[0].to(device), data[1].to(device), data[3].to(device)

                super_outputs, sub_outputs = self.model(inputs)
                super_loss = self.super_criterion(super_outputs, super_labels)
                sub_loss = self.sub_criterion(sub_outputs, sub_labels)
                loss = super_loss + sub_loss
                _, super_predicted = torch.max(super_outputs.data, 1)
                _, sub_predicted = torch.max(sub_outputs.data, 1)

                total += super_labels.size(0)
                super_correct += (super_predicted == super_labels).sum().item()
                sub_correct += (sub_predicted == sub_labels).sum().item()
                running_loss += loss.item()
                running_super_loss += super_loss.item()
                running_sub_loss += sub_loss.item()

        print(f'Validation loss: {running_loss/i:.3f}')
        print(f'Validation superclass loss: {running_super_loss/i:.3f}')
        print(f'Validation subclass loss: {running_sub_loss/i:.3f}')
        print(f'Validation superclass acc: {100 * super_correct / total:.2f} %')
        print(f'Validation subclass acc: {100 * sub_correct / total:.2f} %')

    def test(self, save_to_csv=False, return_predictions=False):
        # threshold = 0.4
        if not self.test_loader:
            raise NotImplementedError('test_loader not specified')

        # Evaluate on test set, in this simple demo no special care is taken for novel/unseen classes
        test_predictions = {'image': [], 'superclass_index': [], 'subclass_index': []}
        with torch.no_grad():
            for i, data in enumerate(self.test_loader):
                inputs, img_name = data[0].to(device), data[1]

                super_outputs, sub_outputs = self.model(inputs)
                super_probs = F.softmax(super_outputs, dim=1)
                sub_probs = F.softmax(sub_outputs, dim=1)

                super_max_probs, super_predicted = torch.max(super_probs, 1)
                sub_max_probs, sub_predicted = torch.max(sub_probs, 1)

                test_predictions['image'].append(img_name[0])
                test_predictions['superclass_index'].append(super_predicted.item())
                test_predictions['subclass_index'].append(sub_predicted.item())

        test_predictions = pd.DataFrame(data=test_predictions)

        if save_to_csv:
            test_predictions.to_csv('example_test_predictions.csv', index=False)

        if return_predictions:
            return test_predictions

# %%
# Init model and trainer
device = 'cuda'
num_super_classes = 4
num_sub_classes = 88
model = EfficientNetV2MultiHead(num_super=num_super_classes, num_sub=num_sub_classes, pretrained=True).to(device)
# print(model)

superclass_weights = superclass_weights.to(device)
subclass_weights = subclass_weights.to(device)
super_criterion = nn.CrossEntropyLoss(weight=superclass_weights)
sub_criterion = nn.CrossEntropyLoss(weight=subclass_weights)

optimizer = optim.Adam(model.parameters(), lr=1e-4)
trainer = Trainer(model, super_criterion, sub_criterion, optimizer, train_loader, val_loader, test_loader)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_v2_s-dd5fe13b.pth
# 100%|██████████| 82.7M/82.7M [00:00<00:00, 237MB/s]

# %%
# !ls data/train_images/

# %%
# Training loop
for param in model.backbone.parameters():
    param.requires_grad = False
last_blocks = list(model.backbone)[-2:]  # Unfreeze last 3 blocks
for block in last_blocks:
    for param in block.parameters():
        param.requires_grad = True

print(f'Start training:')

for epoch in range(20):
    print(f'Epoch {epoch+1}')
    trainer.train_epoch()
    trainer.validate_epoch()
    print('')

print('Finished Training')
# Out:
# Start training:
# Epoch 1

# %%
test_predictions = trainer.test(save_to_csv=True, return_predictions=True)

# %%
# Quick script for evaluating generated csv files with ground truth

super_correct = 0
sub_correct = 0
seen_super_correct = 0
seen_sub_correct = 0
unseen_super_correct = 0
unseen_sub_correct = 0

total = 0
seen_super_total = 0
unseen_super_total = 0
seen_sub_total = 0
unseen_sub_total = 0

for i in range(100):
    super_pred = test_predictions['superclass_index'][i]
    sub_pred = test_predictions['subclass_index'][i]

    super_gt = test_ann_df['superclass_index'][i]
    sub_gt = test_ann_df['subclass_index'][i]

    # Total setting
    if super_pred == super_gt:
        super_correct += 1
    if sub_pred == sub_gt:
        sub_correct += 1
    total += 1

    # Unseen superclass setting
    if super_gt == 3:
        if super_pred == super_gt:
            unseen_super_correct += 1
        if sub_pred == sub_gt:
            unseen_sub_correct += 1
        unseen_super_total += 1
        unseen_sub_total += 1

    # Seen superclass, unseen subclass setting
    if super_gt != 3 and sub_gt == 87:
        if super_pred == super_gt:
            seen_super_correct += 1
        if sub_pred == sub_gt:
            unseen_sub_correct += 1
        seen_super_total += 1
        unseen_sub_total += 1

    # Seen superclass and subclass setting
    if super_gt != 3 and sub_gt != 87:
        if super_pred == super_gt:
            seen_super_correct += 1
        if sub_pred == sub_gt:
            seen_sub_correct += 1
        seen_super_total += 1
        seen_sub_total += 1

print('Superclass Accuracy')
print(f'Overall: {100*super_correct/total:.2f} %')
print(f'Seen: {100*seen_super_correct/seen_super_total:.2f} %')
print(f'Unseen: {100*unseen_super_correct/unseen_super_total:.2f} %')

print('\nSubclass Accuracy')
print(f'Overall: {100*sub_correct/total:.2f} %')
print(f'Seen: {100*seen_sub_correct/seen_sub_total:.2f} %')
print(f'Unseen: {100*unseen_sub_correct/unseen_sub_total:.2f} %')
# Out:
# Superclass Accuracy
# Overall: 37.00 %
# Seen: 52.86 %
# Unseen: 0.00 %
#
# Subclass Accuracy
# Overall: 2.00 %
# Seen: 1.43 %
# Unseen: 3.33 %
